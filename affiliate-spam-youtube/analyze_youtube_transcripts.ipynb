# %%
import json
import math

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import spacy
from tqdm import tqdm

nlp = spacy.load('en_core_web_sm')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

plt.rcParams['figure.dpi'] = 150
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.sans-serif'] = ['Helvetica LT Pro', 'Helvetica', 'Arial', 'DejaVu Sans']
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['grid.color'] = 'lightgray'
plt.rcParams['grid.linewidth'] = 0.5
plt.rcParams["legend.edgecolor"] = 'lightgray'
plt.rcParams["legend.framealpha"] = 1.0
plt.rcParams["legend.fancybox"] = False

# %%
y_test_goldstandard = pd.read_csv('youtube_dev_set_annotated.csv', names=['url', 'label'], index_col=0)
y_test_goldstandard = y_test_goldstandard[y_test_goldstandard['label'] > -1]

# %%
urls = {}
word_tokens = []
pos_tokens = []
result_cutoff = 20
result_ranks = []
num_loaded = []

try:
    infiles = [
        'youtube-transcripts-startpage.jsonl',
        'youtube-transcripts-bing.jsonl',
        'youtube-transcripts-ddg.jsonl',
    ]
    for f in infiles:
        num_loaded.append(0)
        for l in tqdm(open(f, 'r').readlines(), desc='Loading transcripts'):
            transcript = json.loads(l)
            if transcript['url'] in urls or transcript['hit'] > result_cutoff:
                continue

            result_ranks.append(transcript['hit'])
            music_count = sum(1 if t['text'] == '[Music]' else 0 for t in transcript['transcript'])
            text = ' '.join(t['text'] for t in transcript['transcript'] if t['text'] != '[Music]')
            doc = nlp(text, disable=['parser', 'ner', 'lemmatizer', 'textcat'])

            tags = [t.tag_ for t in doc if t.tag_.strip()]
            if len(tags) < 100 or music_count > len(tags):
                continue

            num_loaded[-1] += 1
            urls[transcript['url']] = True
            pos_tokens.append(tags)
            word_tokens.append([t.text for t in doc])
finally:
    urls = list(urls.keys())
    print('Transcripts loaded:', ', '.join(map(str, num_loaded)))
# Out:
# Loading transcripts: 100%|██████████| 4676/4676 [06:48<00:00, 11.45it/s]
# Loading transcripts: 100%|██████████| 979/979 [00:39<00:00, 24.88it/s]
# Loading transcripts: 100%|██████████| 529/529 [00:13<00:00, 40.03it/s]
# Transcripts loaded: 4114, 482, 159

# %%
result_ranks = np.array(result_ranks)
print('Video rank (counting from 1):\n')

print(f'Average @20: {np.average(result_ranks + 1):.1f}')
print(f'Median @20: {np.median(result_ranks + 1):.1f}')
print(f'Num @20: {len(result_ranks + 1)}')
print(f'\nAverage @10: {np.average(result_ranks[result_ranks < 10] + 1):.1f}')
print(f'Median @10: {np.median(result_ranks[result_ranks < 10] + 1):.1f}')
print(f'Num @10: {len(result_ranks[result_ranks < 10] + 1)}')

print(f'\nPortion of videos @10: {len(result_ranks[result_ranks < 10] + 1) / len(result_ranks + 1):.1f}')
# Out:
# Video rank (counting from 1):
#
# Average @20: 10.2
# Median @20: 10.0
# Num @20: 5038
#
# Average @10: 6.0
# Median @10: 6.0
# Num @10: 2691
#
# Portion of videos @10: 0.5

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize, StandardScaler

def _ngrams(t, n):
    return [' '.join(t[i:i+n]) for i in range(len(t) - n)]

def _analyzer(t):
    return t + _ngrams(t, 2) + _ngrams(t, 3) + _ngrams(t, 4)

pos_vectorizer = CountVectorizer(analyzer=_analyzer, max_features=150)
pos_count_matrix = pos_vectorizer.fit_transform(pos_tokens)
X = normalize(pos_count_matrix.toarray(), norm='l1', axis=1)

# word_vectorizer = CountVectorizer(analyzer=_analyzer, max_features=150)
# X = normalize(word_vectorizer.fit_transform(word_tokens).toarray(), norm='l1', axis=1)
# X = np.hstack((X, normalize(word_vectorizer.fit_transform(word_tokens).toarray(), norm='l1', axis=1)))

X_train = []
X_test = []
y_true = []
urls_train = []
urls_test = []

for i in range(X.shape[0]):
    if urls[i] in y_test_goldstandard.index:
        X_test.append(X[i])
        urls_test.append(urls[i])
        y_true.append(y_test_goldstandard.loc[urls[i]]['label'])
    else:
        X_train.append(X[i])
        urls_train.append(urls[i])

X_train = np.array(X_train)
X_test = np.array(X_test)
y_true = np.array(y_true)

# X_train, X_test, urls_train, urls_test = train_test_split(token_rel_counts, urls, test_size=len(y_test_goldstandard))

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
pos_freqs = np.array(pos_count_matrix.sum(axis=0)).flatten()
print('POS n-grams by frequency:')
print([p[0].replace(' ', '+') for p in sorted(pos_vectorizer.vocabulary_.items(), key=lambda x: pos_freqs[x[1]], reverse=True)])
# Out:
# POS n-grams by frequency:
# ['NN', 'IN', 'DT', 'PRP', 'RB', 'JJ', 'VB', 'DT+NN', 'NNS', 'VBZ', 'VBP', 'CC', 'IN+DT', 'NN+IN', 'JJ+NN', 'PRP+VBP', 'NN+NN', 'DT+JJ', 'VBG', 'TO', 'CD', 'IN+DT+NN', 'NNP', 'TO+VB', 'IN+PRP', 'MD', 'VBN', 'DT+JJ+NN', 'NN+CC', 'PRP$', 'RB+RB', 'PRP+VBZ', 'VBD', 'VB+DT', 'IN+NN', 'DT+NN+IN', 'MD+VB', 'NN+IN+DT', 'PRP+MD', 'NNS+IN', 'NN+VBZ', 'NN+PRP', 'VBZ+DT', 'RB+VB', 'NN+RB', 'WDT', 'RB+IN', '_SP', 'UH', 'RB+JJ', 'JJ+NNS', 'RP', 'PRP+MD+VB', 'VBZ+RB', 'VB+PRP', 'NN+NNS', 'DT+NN+NN', 'CC+PRP', 'PRP$+NN', 'VBP+RB', 'VB+IN', 'IN+DT+JJ', 'JJ+NN+IN', 'IN+PRP+VBP', 'DT+NNS', 'RB+PRP', 'JJ+IN', 'VBP+DT', 'NN+IN+DT+NN', 'IN+PRP$', 'NN+DT', 'PRP+RB', 'NNS+CC', 'PRP+VBD', 'IN+JJ', 'VB+DT+NN', 'WRB', '.', 'RB+DT', 'JJ+NN+NN', 'CC+DT', 'VBN+IN', 'JJ+JJ', 'VBP+VBG', 'PRP+VBP+RB', 'DT+VBZ', 'JJR', 'NN+WDT', 'CD+NNS', 'CC+RB', 'PRP+VBP+VBG', 'TO+VB+DT', 'NN+NN+NN', 'NN+IN+NN', 'NNP+NNP', 'CD+NN', 'IN+DT+JJ+NN', 'IN+DT+NN+IN', 'VBG+TO', 'NN+IN+PRP', ',', 'VBG+TO+VB', 'NN+NN+IN', 'VBZ+IN', 'DT+NN+IN+DT', 'VBP+PRP', 'NN+PRP+VBP', 'DT+JJ+NN+IN', 'VBZ+JJ', 'IN+CD', 'JJ+CC', 'DT+NNP', 'PRP+VBP+DT', 'DT+NN+VBZ', 'DT+NN+CC', 'WDT+VBZ', 'NNS+VBP', 'IN+NNS', 'VBZ+DT+NN', 'IN+PRP$+NN', 'NNS+IN+DT', 'PRP+IN', 'VBZ+DT+JJ', 'IN+VBG', 'IN+IN', 'CC+NN', 'VBG+DT', 'NNS+RB', 'WP', 'PRP+VBZ+RB', 'DT+NN+PRP', 'MD+RB', 'CC+VB', 'VBG+IN', 'NNP+NN', 'NNS+PRP', 'VB+RB', 'VBP+IN', 'NN+JJ', 'RB+IN+DT', 'JJS', 'DT+NN+RB', 'RB+PRP+VBP', 'VB+JJ', 'HYPH', 'NN+NN+CC', 'VBP+VBN', 'IN+DT+NN+NN', 'NN+TO', 'WRB+PRP']

# %%
from sklearn.cluster import DBSCAN, KMeans, SpectralClustering
from sklearn.manifold import TSNE

n_clusters = 2
y_train = SpectralClustering(n_clusters=n_clusters).fit_predict(X_train)
# Clustering my inadvertently swap labels
if np.sum(y_train) / y_train.shape[0] < 0.5:
    y_train = 1 - y_train

print('Spam labels:', y_train.shape[0] - np.sum(y_train))
print('Non-Spam labels:', np.sum(y_train))
# Out:
# Spam labels: 2202
# Non-Spam labels: 2353

# %%
X_3d = TSNE(n_components=3, random_state=29, init='random', method='barnes_hut', n_jobs=-1).fit_transform(np.vstack((X_train, X_test)))
X_train_3d = X_3d[:X_train.shape[0], :]
X_test_3d = X_3d[X_train.shape[0]:, :]

# %%
def _ceil10(n):
    return int(math.ceil(n / 10) * 10)

def _floor10(n):
    return int(math.floor(n / 10) * 10)

def _config_axis(ax, data):
    ax.set_ticks(np.linspace(_floor10(np.min(data)), _ceil10(np.max(data)), 3))
    ax.set_ticklabels([])
    ax.pane.fill = False
    ax.pane.set_linewidth(0.5)
    ax.pane.set_alpha(1.0)
    ax.pane.set_edgecolor(plt.rcParams['grid.color'])

def _plot_scatter(X_3d, y, title, legend_title, outfile=None, subsample=1.0):
    fig = plt.figure(figsize=(4, 4))
    ax = fig.add_subplot(projection='3d', computed_zorder=True)

    if subsample < 1.0:
        sampler = np.random.choice(X_3d.shape[0], int(X_3d.shape[0] * subsample))
        X_3d_sampled = X_3d[sampler]
        y_sampled = y[sampler]
    else:
        X_3d_sampled = X_3d
        y_sampled = y

    labels = ['Spam', 'Non-Spam']
    for i in range(len(labels)):
        scatter_data = X_3d_sampled[y_sampled == i]
        ax.scatter(scatter_data[:, 0], scatter_data[:, 1], scatter_data[:, 2], label=f'{labels[i]}')

    scatter_data_projected = np.array(X_3d_sampled)
    scatter_data_projected[:, 2] = np.min(scatter_data_projected[:, 2])
    ax.scatter(scatter_data_projected[:, 0], scatter_data_projected[:, 1], scatter_data_projected[:, 2], c='lightgray', s=15, lw=0, alpha=0.4)

    _config_axis(ax.axes.xaxis, X_3d[:, 0])
    _config_axis(ax.axes.yaxis, X_3d[:, 1])
    _config_axis(ax.axes.zaxis, X_3d[:, 2])
    ax.axes.margins(0, 0, 0, tight=False)

    plt.legend(labelspacing=0.4, handletextpad=0, ncols=2, columnspacing=1.0, handlelength=1.5, title=legend_title, alignment='left')
    plt.title(title, y=0.07, x=0.2, fontdict=dict(fontsize=10))
    fig.canvas.draw()
    plt.tight_layout()
    if outfile:
        fig.savefig(outfile)
    plt.show()

_plot_scatter(X_train_3d, y_train, 'Training Set', 'Cluster Labels', 'scatter-clusters.pdf', .33)
_plot_scatter(X_test_3d, y_true, 'Test Set', 'Ground Truth', 'scatter-truth.pdf')

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import balanced_accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC

clf = LogisticRegression()
clf.fit(X_train[y_train > -1], y_train[y_train > -1])
y_pred = clf.predict(X_test)
y_scores = clf.decision_function(X_test) if hasattr(clf, 'decision_function') else None

# Trivial classifiers
# y_pred = X_test[:, pos_vectorizer.vocabulary_['NN']] < 0.1
# y_pred = X_test[:, pos_vectorizer.vocabulary_['PRP']] > 0.035

print(f'Accuracy (balanced): {balanced_accuracy_score(y_true, y_pred):.2f}')
if y_scores is not None:
    print(f'AUROC: {roc_auc_score(y_true, y_scores):.2f}')

print('\nNon-spam:')
print(f'Precision: {precision_score(y_true, y_pred):.2f}')
print(f'Recall: {recall_score(y_true, y_pred):.2f}')
print(f'F1: {f1_score(y_true, y_pred):.2f}')

print('\nSpam:')
print(f'Precision: {precision_score(y_true, y_pred, pos_label=0):.2f}')
print(f'Recall: {recall_score(y_true, y_pred, pos_label=0):.2f}')
print(f'F1: {f1_score(y_true, y_pred, pos_label=0):.2f}')
# Out:
# Accuracy (balanced): 0.88
# AUROC: 0.93
#
# Non-spam:
# Precision: 0.97
# Recall: 0.81
# F1: 0.88
#
# Spam:
# Precision: 0.73
# Recall: 0.96
# F1: 0.83

# %%
display(pd.DataFrame(zip(urls_test, y_pred), columns=['url', 'label']).sort_values(by=['label']))
# Out:
#                                              url  label
# 0    https://www.youtube.com/watch?v=7Bnm--PPxeM      0
# 90   https://www.youtube.com/watch?v=IinqvCkSz54      0
# 88   https://www.youtube.com/watch?v=4S6hnGSvGPE      0
# 87   https://www.youtube.com/watch?v=OOO4N7AHBDg      0
# 86   https://www.youtube.com/watch?v=4Ks2tXdRwQM      0
# 83   https://www.youtube.com/watch?v=QFWwD8uH5-Y      0
# 156  https://www.youtube.com/watch?v=7rvuez57Mno      0
# 158  https://www.youtube.com/watch?v=WC0HWzaiu9Q      0
# 79   https://www.youtube.com/watch?v=evU4LQNlhVA      0
# 78   https://www.youtube.com/watch?v=c392JGmMNmI      0
# 77   https://www.youtube.com/watch?v=d2f2J_hcBwE      0
# 75   https://www.youtube.com/watch?v=gYucSC8hhNU      0
# 91   https://www.youtube.com/watch?v=UqEUox4Q6fs      0
# 74   https://www.youtube.com/watch?v=Em9909eHYKw      0
# 161  https://www.youtube.com/watch?v=iX95bpqBh7Q      0
# 70   https://www.youtube.com/watch?v=pSaeawvCGhM      0
# 162  https://www.youtube.com/watch?v=sHgN1RM3H7c      0
# 163  https://www.youtube.com/watch?v=2cPq48AqIgw      0
# 164  https://www.youtube.com/watch?v=wgOY0hKa9ig      0
# 66   https://www.youtube.com/watch?v=r-Pob6gCPZ8      0
# 134  https://www.youtube.com/watch?v=q-LcsqFzkT8      0
# 64   https://www.youtube.com/watch?v=WEbjOB9O26s      0
# 165  https://www.youtube.com/watch?v=a57Eu6q9K5E      0
# 62   https://www.youtube.com/watch?v=Tg5K7olJfZc      0
# 61   https://www.youtube.com/watch?v=9gH7eRG-Ufo      0
# 72   https://www.youtube.com/watch?v=EbKaHPrcbAM      0
# 167  https://www.youtube.com/watch?v=XnKZq4RqPlk      0
# 152  https://www.youtube.com/watch?v=Kexd6X14pDE      0
# 94   https://www.youtube.com/watch?v=qodSERnF2vw      0
# 129  https://www.youtube.com/watch?v=JzFB8yjZcZw      0
# 128  https://www.youtube.com/watch?v=Q3a3w3GtbJQ      0
# 135  https://www.youtube.com/watch?v=KeCSw70IGTY      0
# 136  https://www.youtube.com/watch?v=SP0_-s85JuQ      0
# 125  https://www.youtube.com/watch?v=FBftTMJGIU0      0
# 124  https://www.youtube.com/watch?v=ZNgyeAaFM4U      0
# 123  https://www.youtube.com/watch?v=TnQSncRJLCc      0
# 122  https://www.youtube.com/watch?v=cfFpGrdt8IA      0
# 140  https://www.youtube.com/watch?v=tWoucO2nIlE      0
# 117  https://www.youtube.com/watch?v=D9PtZ0qCurU      0
# 141  https://www.youtube.com/watch?v=FttkdlR_qAU      0
# 93   https://www.youtube.com/watch?v=4r6nXm174UE      0
# 115  https://www.youtube.com/watch?v=hubT3r4F_Zc      0
# 143  https://www.youtube.com/watch?v=byBd5sXryy8      0
# 144  https://www.youtube.com/watch?v=wu09em2MjME      0
# 110  https://www.youtube.com/watch?v=bJ9nLMCQYNw      0
# 109  https://www.youtube.com/watch?v=wlYfGeQHURM      0
# 105  https://www.youtube.com/watch?v=kaMLgLpEYN4      0
# 104  https://www.youtube.com/watch?v=Mu6GpA5_vpY      0
# 103  https://www.youtube.com/watch?v=y4MOkiz4shg      0
# 198  https://www.youtube.com/watch?v=vGi__-kx3nk      0
# 98   https://www.youtube.com/watch?v=ke5rDEffzNY      0
# 96   https://www.youtube.com/watch?v=PXdTgy1nU_M      0
# 95   https://www.youtube.com/watch?v=uNkKokcx7Kk      0
# 114  https://www.youtube.com/watch?v=moEV09VG_4c      0
# 170  https://www.youtube.com/watch?v=gU_SQoXa0a4      0
# 65   https://www.youtube.com/watch?v=ZjkdPq0Cw-c      0
# 54   https://www.youtube.com/watch?v=j1wsf2qs40k      0
# 31   https://www.youtube.com/watch?v=BnSS0LhTX3c      0
# 30   https://www.youtube.com/watch?v=zS6Iq1Lx4Ko      0
# 55   https://www.youtube.com/watch?v=VUbTLWwE6Xg      0
# 24   https://www.youtube.com/watch?v=MXIovhY5xHU      0
# 22   https://www.youtube.com/watch?v=zmA5odgVToM      0
# 20   https://www.youtube.com/watch?v=vqXty-GV-a8      0
# 19   https://www.youtube.com/watch?v=R3lLu7Wh2AI      0
# 191  https://www.youtube.com/watch?v=kM1I1xOwPx8      0
# 192  https://www.youtube.com/watch?v=pL5uttjPWZE      0
# 15   https://www.youtube.com/watch?v=5MJAs3pT01s      0
# 14   https://www.youtube.com/watch?v=bdcPbmr9il8      0
# 12   https://www.youtube.com/watch?v=NAOO7L_BvAs      0
# 11   https://www.youtube.com/watch?v=IuUlOHCwEn0      0
# 9    https://www.youtube.com/watch?v=MfovWwO5mlA      0
# 8    https://www.youtube.com/watch?v=rXiIGMH8qko      0
# 7    https://www.youtube.com/watch?v=IXy5JyFsgB0      0
# 6    https://www.youtube.com/watch?v=pTD0Bj7J_bQ      0
# 5    https://www.youtube.com/watch?v=FfDp-xZxrVc      0
# 4    https://www.youtube.com/watch?v=q-i6X1q5aZI      0
# 197  https://www.youtube.com/watch?v=ylZeSBjtdmY      0
# 1    https://www.youtube.com/watch?v=4SKYxXbREc8      0
# 32   https://www.youtube.com/watch?v=ijJ2dDHIPwQ      0
# 34   https://www.youtube.com/watch?v=9t5xF5_5qcc      0
# 26   https://www.youtube.com/watch?v=8-Ic7f4CjNU      0
# 176  https://www.youtube.com/watch?v=U8EkLn4wYAU      0
# 43   https://www.youtube.com/watch?v=kYcbS6-LwF4      0
# 42   https://www.youtube.com/watch?v=TJJ-MDVlxkY      0
# 53   https://www.youtube.com/watch?v=TSGFJXBQHNs      0
# 181  https://www.youtube.com/watch?v=7U0bG1exavw      0
# 180  https://www.youtube.com/watch?v=fc2xztNkPyU      0
# 174  https://www.youtube.com/watch?v=h_UDVCGmdMw      0
# 50   https://www.youtube.com/watch?v=7WYDHP5Q4Zo      0
# 173  https://www.youtube.com/watch?v=cyex_tMCd7E      0
# 183  https://www.youtube.com/watch?v=7Xcxw3fn4X8      0
# 49   https://www.youtube.com/watch?v=_QsaSZDrDKQ      0
# 48   https://www.youtube.com/watch?v=0k1JVYW5mbU      0
# 193  https://www.youtube.com/watch?v=nENQ-TLBYvI      1
# 175  https://www.youtube.com/watch?v=dBTbV-S-8DY      1
# 142  https://www.youtube.com/watch?v=rVGDiLnMx9c      1
# 194  https://www.youtube.com/watch?v=u8vUyVVCYnQ      1
# 157  https://www.youtube.com/watch?v=gy2qcxEwtk8      1
# 138  https://www.youtube.com/watch?v=E0Po5L6ODJg      1
# 137  https://www.youtube.com/watch?v=lYSuLSLlkXs      1
# 172  https://www.youtube.com/watch?v=nDzWjwo93CQ      1
# 171  https://www.youtube.com/watch?v=T7bN3f70B44      1
# 166  https://www.youtube.com/watch?v=no17-7MzbjY      1
# 196  https://www.youtube.com/watch?v=rhBvfj4XMxE      1
# 168  https://www.youtube.com/watch?v=13ggcvTHETw      1
# 169  https://www.youtube.com/watch?v=UK2eTs8mvsQ      1
# 195  https://www.youtube.com/watch?v=FdNb3fCcGRs      1
# 139  https://www.youtube.com/watch?v=uezdE6O9vY8      1
# 147  https://www.youtube.com/watch?v=XKQJhe9n_ug      1
# 146  https://www.youtube.com/watch?v=ripeQrS4EVI      1
# 182  https://www.youtube.com/watch?v=9TYDzveDoC0      1
# 184  https://www.youtube.com/watch?v=t91MjHzT4gU      1
# 155  https://www.youtube.com/watch?v=6KuWB2xQsMc      1
# 154  https://www.youtube.com/watch?v=O-hxxqmvbUc      1
# 159  https://www.youtube.com/watch?v=UoJWCy-Pue8      1
# 153  https://www.youtube.com/watch?v=XZ4qVV51WRo      1
# 185  https://www.youtube.com/watch?v=YOJ5T2nLLD0      1
# 186  https://www.youtube.com/watch?v=bpdTqQhX4_8      1
# 187  https://www.youtube.com/watch?v=5OFt2T8aH9I      1
# 145  https://www.youtube.com/watch?v=3H9660N7jc4      1
# 179  https://www.youtube.com/watch?v=4QrSF0sb-yM      1
# 178  https://www.youtube.com/watch?v=wD4rC1aIXMU      1
# 189  https://www.youtube.com/watch?v=Zxmw9n6yNFs      1
# 151  https://www.youtube.com/watch?v=5MBSKXttelc      1
# 160  https://www.youtube.com/watch?v=s0fKeJbB0lk      1
# 190  https://www.youtube.com/watch?v=_gUWe7MwswU      1
# 150  https://www.youtube.com/watch?v=9d5ZXpqT30c      1
# 149  https://www.youtube.com/watch?v=NsNbKL_0B98      1
# 148  https://www.youtube.com/watch?v=AQ49Fl9XMfw      1
# 177  https://www.youtube.com/watch?v=gdZmZOaHuOQ      1
# 188  https://www.youtube.com/watch?v=tmoQAAWPZhQ      1
# 133  https://www.youtube.com/watch?v=ZtKvMlituJg      1
# 99   https://www.youtube.com/watch?v=wfs7BgNowNA      1
# 131  https://www.youtube.com/watch?v=m9pX3KGgplI      1
# 58   https://www.youtube.com/watch?v=DdvhKdLKN2E      1
# 57   https://www.youtube.com/watch?v=3ZsWD4N0yds      1
# 56   https://www.youtube.com/watch?v=1Qt3X6TCMcU      1
# 52   https://www.youtube.com/watch?v=kIeKwhDcE5g      1
# 51   https://www.youtube.com/watch?v=GEyoqkJDhEc      1
# 47   https://www.youtube.com/watch?v=-88ISV3GaIg      1
# 46   https://www.youtube.com/watch?v=7SZGhxukwr0      1
# 45   https://www.youtube.com/watch?v=Yx9llZFkKXc      1
# 44   https://www.youtube.com/watch?v=r2Da2m1A32Q      1
# 41   https://www.youtube.com/watch?v=eemkTcS0zsM      1
# 40   https://www.youtube.com/watch?v=Kgavos7pBd4      1
# 39   https://www.youtube.com/watch?v=oNJUBfPSjeg      1
# 38   https://www.youtube.com/watch?v=JGzC729BhVA      1
# 37   https://www.youtube.com/watch?v=w2sxLvDJVaU      1
# 59   https://www.youtube.com/watch?v=GXsV7yfvR7c      1
# 36   https://www.youtube.com/watch?v=AC6oYE88wLE      1
# 33   https://www.youtube.com/watch?v=HGpFFUer3S0      1
# 29   https://www.youtube.com/watch?v=hn2nmsG5_l4      1
# 28   https://www.youtube.com/watch?v=b6GO6xBaf9o      1
# 27   https://www.youtube.com/watch?v=P8xilUdFS08      1
# 25   https://www.youtube.com/watch?v=THy25FgIW8o      1
# 23   https://www.youtube.com/watch?v=oyanZWMo_-o      1
# 21   https://www.youtube.com/watch?v=AYXdr7G4EHY      1
# 18   https://www.youtube.com/watch?v=IUVoy5gzutg      1
# 17   https://www.youtube.com/watch?v=926Wm1JJCCM      1
# 16   https://www.youtube.com/watch?v=ReZDPS8Wdj0      1
# 13   https://www.youtube.com/watch?v=_-WxKl_AVTE      1
# 10   https://www.youtube.com/watch?v=fdJT6vQGp3I      1
# 3    https://www.youtube.com/watch?v=ijlVoqn2UHI      1
# 2    https://www.youtube.com/watch?v=eyUjzVjEAM8      1
# 35   https://www.youtube.com/watch?v=nU5RRPSS044      1
# 132  https://www.youtube.com/watch?v=KwXpMKiwGD8      1
# 60   https://www.youtube.com/watch?v=8X5i72gdefA      1
# 67   https://www.youtube.com/watch?v=S1WQpt10vDQ      1
# 130  https://www.youtube.com/watch?v=KJemQuzQCWQ      1
# 127  https://www.youtube.com/watch?v=-hOMd5ZkQsw      1
# 126  https://www.youtube.com/watch?v=KhXCLrY46MY      1
# 121  https://www.youtube.com/watch?v=iqTCHfJ5Dvs      1
# 120  https://www.youtube.com/watch?v=VoQ06BDvhus      1
# 119  https://www.youtube.com/watch?v=5pgk3LFFGCQ      1
# 118  https://www.youtube.com/watch?v=61c0ewrXPdA      1
# 116  https://www.youtube.com/watch?v=INhDkqHKiPQ      1
# 113  https://www.youtube.com/watch?v=mlYBLokOzIY      1
# 112  https://www.youtube.com/watch?v=-OdclnwFuac      1
# 111  https://www.youtube.com/watch?v=e6Kzs254MmU      1
# 108  https://www.youtube.com/watch?v=7tupPWteS5w      1
# 107  https://www.youtube.com/watch?v=tQvILNVKZcI      1
# 106  https://www.youtube.com/watch?v=inThod9IAII      1
# 63   https://www.youtube.com/watch?v=twzGo85lmOk      1
# 102  https://www.youtube.com/watch?v=Pf-V08sXLgE      1
# 100  https://www.youtube.com/watch?v=qcgz3-XyNkI      1
# 97   https://www.youtube.com/watch?v=4EBaKgtOW9k      1
# 92   https://www.youtube.com/watch?v=aCmxa-RsoCM      1
# 89   https://www.youtube.com/watch?v=o3yNf77_BKQ      1
# 85   https://www.youtube.com/watch?v=Bvf4D5sP4W8      1
# 84   https://www.youtube.com/watch?v=arPyzyDep6s      1
# 82   https://www.youtube.com/watch?v=vJz_-peDyE4      1
# 81   https://www.youtube.com/watch?v=strf2b54WuA      1
# 80   https://www.youtube.com/watch?v=Og0FCglYGmA      1
# 76   https://www.youtube.com/watch?v=AIwMdPKnWqY      1
# 73   https://www.youtube.com/watch?v=7QUizHRzIqU      1
# 71   https://www.youtube.com/watch?v=7zc-5FN4jxs      1
# 69   https://www.youtube.com/watch?v=SJ13It0ZdnU      1
# 68   https://www.youtube.com/watch?v=vDPk1qaxSS4      1
# 101  https://www.youtube.com/watch?v=DPp6oyGGAdc      1
# 199  https://www.youtube.com/watch?v=HV55pnd0x14      1

# %%
def _plot_top_ngrams(X, y, coef, title, outfile=None):
    # coef_argsorted = np.argsort(coef)
    # coef_argsorted = np.argsort(coef)[::-1]
    coef_argsorted = np.argsort(np.abs(coef))[::-1]
    ngrams_sorted = [k.replace(' ', '+') for k, _ in sorted(pos_vectorizer.vocabulary_.items(), key=lambda i: i[1])]
    print('POS n-grams by importance:')
    print([ngrams_sorted[coef_argsorted[i]] for i in range(len(ngrams_sorted))])

    fig, axs = plt.subplots(3, 3, sharex='all', sharey='all', figsize=(5, 6))
    for i, ax in enumerate(axs.flatten()):
        for c, label in enumerate(['Spam', 'Non-Spam']):
            ax.hist(X[y == c, coef_argsorted[i]], label=label, bins=np.arange(-0.01, 0.17, 0.003), histtype='step')
        ax.set_xlabel(ngrams_sorted[coef_argsorted[i]])
        ax.xaxis.set_label_position('top')

    fig.supxlabel('Frequency', x=0.56)
    fig.supylabel('Number of Transcripts')
    lines, labels = axs[0, 0].get_legend_handles_labels()
    plt.figlegend(lines, labels, loc='upper right', bbox_to_anchor=(0.972, 0.902), ncol=1, labelspacing=0.4)
    plt.suptitle(title, x=0.56)
    plt.tight_layout(pad=1.0, w_pad=0.7, h_pad=0.7)
    if outfile:
        fig.savefig(outfile)
    plt.show()

_plot_top_ngrams(X_train, y_train, clf.coef_[0], 'Discriminative POS N-Grams (Clustering)', 'pos-ngrams-cluster.pdf')
_plot_top_ngrams(X_test, y_true, clf.coef_[0], 'Discriminative POS N-Grams (Ground Truth)', 'pos-ngrams-truth.pdf')
# Out:
# POS n-grams by importance:
# ['NN', 'PRP', 'RB', 'JJ', 'NN+NN', 'PRP+VBP', 'VBP', 'NNS', 'JJ+NN', 'CD', 'RB+RB', 'IN+PRP', 'VB', 'NNP', 'NN+VBZ', 'UH', 'VBN', 'NN+IN', 'NN+NNS', 'CC+PRP', 'NN+NN+NN', 'IN', 'VBD', 'RB+PRP', 'JJ+NN+NN', 'IN+JJ', 'VBP+RB', 'NNS+IN', 'VBN+IN', 'IN+NN', 'VB+PRP', 'VBG+TO', 'VBP+VBG', 'PRP+VBD', 'VBG+TO+VB', 'PRP+VBP+RB', 'PRP+VBP+VBG', 'PRP+MD', 'VBZ', 'DT+JJ', 'PRP+RB', 'NN+DT', 'DT+VBZ', 'IN+PRP+VBP', 'JJ+NNS', 'CD+NN', 'RP', 'HYPH', 'PRP+MD+VB', 'NNP+NNP', 'JJ+JJ', 'RB+IN', 'RB+PRP+VBP', 'RB+JJ', 'DT+NN+NN', 'TO+VB', 'CC+NN', 'RB+VB', 'VBZ+DT', 'VBP+PRP', 'NN+PRP', 'DT', 'IN+CD', 'NN+NN+IN', 'NN+RB', 'CC+RB', 'NN+PRP+VBP', 'DT+JJ+NN', 'CD+NNS', 'WRB', 'VBZ+JJ', 'TO', 'VBZ+RB', 'NN+JJ', 'NNP+NN', 'WP', 'NN+CC', 'PRP$', 'PRP+VBP+DT', 'JJS', 'JJ+NN+IN', 'VB+DT', 'IN+VBG', 'RB+DT', 'WRB+PRP', 'NNS+CC', 'PRP+VBZ', 'VBZ+DT+JJ', 'VBP+DT', 'DT+NN+VBZ', 'IN+DT+JJ', 'VBG', 'JJ+IN', 'NN+IN+NN', 'NNS+VBP', 'PRP+VBZ+RB', 'NN+IN+PRP', 'NNS+IN+DT', 'MD', 'PRP+IN', 'DT+NNP', 'NN+NN+CC', 'VBP+IN', 'DT+NN+RB', 'NN+IN+DT', 'DT+NN+PRP', 'NN+TO', '.', 'IN+PRP$', 'DT+NN+CC', 'VB+IN', 'JJ+CC', 'RB+IN+DT', 'IN+DT+JJ+NN', 'VB+RB', 'DT+NN+IN', 'VBP+VBN', 'PRP$+NN', 'WDT+VBZ', 'DT+JJ+NN+IN', 'IN+DT+NN+NN', 'MD+VB', 'TO+VB+DT', 'IN+NNS', 'DT+NNS', 'IN+IN', 'VB+JJ', 'NN+WDT', 'CC+DT', 'NN+IN+DT+NN', 'VBZ+IN', 'IN+PRP$+NN', '_SP', ',', 'VB+DT+NN', 'DT+NN+IN+DT', 'NNS+RB', 'DT+NN', 'JJR', 'VBZ+DT+NN', 'VBG+DT', 'CC+VB', 'NNS+PRP', 'MD+RB', 'IN+DT', 'CC', 'VBG+IN', 'WDT', 'IN+DT+NN', 'IN+DT+NN+IN']
# POS n-grams by importance:
# ['NN', 'PRP', 'RB', 'JJ', 'NN+NN', 'PRP+VBP', 'VBP', 'NNS', 'JJ+NN', 'CD', 'RB+RB', 'IN+PRP', 'VB', 'NNP', 'NN+VBZ', 'UH', 'VBN', 'NN+IN', 'NN+NNS', 'CC+PRP', 'NN+NN+NN', 'IN', 'VBD', 'RB+PRP', 'JJ+NN+NN', 'IN+JJ', 'VBP+RB', 'NNS+IN', 'VBN+IN', 'IN+NN', 'VB+PRP', 'VBG+TO', 'VBP+VBG', 'PRP+VBD', 'VBG+TO+VB', 'PRP+VBP+RB', 'PRP+VBP+VBG', 'PRP+MD', 'VBZ', 'DT+JJ', 'PRP+RB', 'NN+DT', 'DT+VBZ', 'IN+PRP+VBP', 'JJ+NNS', 'CD+NN', 'RP', 'HYPH', 'PRP+MD+VB', 'NNP+NNP', 'JJ+JJ', 'RB+IN', 'RB+PRP+VBP', 'RB+JJ', 'DT+NN+NN', 'TO+VB', 'CC+NN', 'RB+VB', 'VBZ+DT', 'VBP+PRP', 'NN+PRP', 'DT', 'IN+CD', 'NN+NN+IN', 'NN+RB', 'CC+RB', 'NN+PRP+VBP', 'DT+JJ+NN', 'CD+NNS', 'WRB', 'VBZ+JJ', 'TO', 'VBZ+RB', 'NN+JJ', 'NNP+NN', 'WP', 'NN+CC', 'PRP$', 'PRP+VBP+DT', 'JJS', 'JJ+NN+IN', 'VB+DT', 'IN+VBG', 'RB+DT', 'WRB+PRP', 'NNS+CC', 'PRP+VBZ', 'VBZ+DT+JJ', 'VBP+DT', 'DT+NN+VBZ', 'IN+DT+JJ', 'VBG', 'JJ+IN', 'NN+IN+NN', 'NNS+VBP', 'PRP+VBZ+RB', 'NN+IN+PRP', 'NNS+IN+DT', 'MD', 'PRP+IN', 'DT+NNP', 'NN+NN+CC', 'VBP+IN', 'DT+NN+RB', 'NN+IN+DT', 'DT+NN+PRP', 'NN+TO', '.', 'IN+PRP$', 'DT+NN+CC', 'VB+IN', 'JJ+CC', 'RB+IN+DT', 'IN+DT+JJ+NN', 'VB+RB', 'DT+NN+IN', 'VBP+VBN', 'PRP$+NN', 'WDT+VBZ', 'DT+JJ+NN+IN', 'IN+DT+NN+NN', 'MD+VB', 'TO+VB+DT', 'IN+NNS', 'DT+NNS', 'IN+IN', 'VB+JJ', 'NN+WDT', 'CC+DT', 'NN+IN+DT+NN', 'VBZ+IN', 'IN+PRP$+NN', '_SP', ',', 'VB+DT+NN', 'DT+NN+IN+DT', 'NNS+RB', 'DT+NN', 'JJR', 'VBZ+DT+NN', 'VBG+DT', 'CC+VB', 'NNS+PRP', 'MD+RB', 'IN+DT', 'CC', 'VBG+IN', 'WDT', 'IN+DT+NN', 'IN+DT+NN+IN']
